# %%
import pandas as pd 
df=pd.read_csv('data/portfolio.csv')
# print(df)
df.dtypes
df.shape
df_nw= pd.read_csv('data/VWCE.DE.csv', header=[0,1],index_col=0)
# df_nw.set_index('Price')
# df_nw.to_datetime()
df_nw.head()
# df_nw.dtypes
# df.info()
# df_nw.columns
close=df_nw["Close"]
df_nw.index=pd.to_datetime(df_nw.index)


close.head()
print(df_nw.index)
print(type(df_nw.index[0]))
# Out:
# DatetimeIndex(['2019-07-29', '2019-07-30', '2019-07-31', '2019-08-01',
#                '2019-08-02', '2019-08-05', '2019-08-06', '2019-08-07',
#                '2019-08-08', '2019-08-09',
#                ...
#                '2026-02-23', '2026-02-24', '2026-02-25', '2026-02-26',
#                '2026-02-27', '2026-03-02', '2026-03-03', '2026-03-04',
#                '2026-03-05', '2026-03-06'],
#               dtype='datetime64[us]', name='Date', length=1680, freq=None)
# <class 'pandas.Timestamp'>
